# %%
from datasets import load_dataset

dataset = load_dataset("lawcompany/KLAID")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/taehwan/Workspace/project/projects/keggle/klaid/law_classification/klaid.ipynb 셀 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/taehwan/Workspace/project/projects/keggle/klaid/law_classification/klaid.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from datasets import load_dataset
#       <a href='vscode-notebook-cell:/Users/taehwan/Workspace/project/projects/keggle/klaid/law_classification/klaid.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> dataset = load_dataset("lawcompany/KLAID")
#
# ModuleNotFoundError: No module named 'datasets'
